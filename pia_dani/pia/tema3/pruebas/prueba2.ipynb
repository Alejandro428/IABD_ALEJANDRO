# %%
import numpy as np
from sklearn.datasets import load_iris

# %%
iris = load_iris()

flower_type = iris.target[0:99]

print(np.unique(flower_type))

flower_type = iris.target[0:]

print(np.unique(flower_type))
# Out:
# [0 1]
# [0 1 2]
