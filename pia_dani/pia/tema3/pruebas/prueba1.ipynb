# %%
import numpy as np

# %%
a = np.array([3, 7, 9, 8, 2, 1])

f = a>=5

print(f)
print(a[f])
# Out:
# [False  True  True  True False False]
# [7 9 8]

# %%
convalidados = np.array([0, 0, 0, 1, 0, 0])
notas = np.array([3, 7, 9, 0, 2, 0])
alumnos = np.array(['a', 'b', 'c', 'd', 'e', 'f'])

print(alumnos[(notas>=5) | (convalidados==1)])
# Out:
# ['b' 'c' 'd']
