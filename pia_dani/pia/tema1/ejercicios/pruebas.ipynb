# %%
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
datos = [
    [1, 2, 3, [10, 20, 10]],
    [4, 5, 6, [30, 40, 50]],
    [7, 8, 9, [70, 80, 90]]
]

for epocas, lr, dropout, (c1, c2, c3) in datos:
    print(f"Entrenando con {epocas} épocas, tasa de aprendizaje {lr}, dropout {dropout}, capas {c1}, {c2}, {c3}")

print("\n--- Variación con listas de diferentes longitudes ---\n")

datos = [
    [1, 2, 3, [10, 20, 30, 20, 10]],
    [4, 5, 6, [30, 40, 50, 40, 30, 20]],
    [7, 8, 9, [70, 80, 90]]
]

for epocas, lr, dropout, capas in datos:
    print(f"Entrenando con {epocas} épocas, tasa de aprendizaje {lr}, dropout {dropout}, capas {capas}")
# Out:
# Entrenando con 1 épocas, tasa de aprendizaje 2, dropout 3, capas 10, 20, 10
# Entrenando con 4 épocas, tasa de aprendizaje 5, dropout 6, capas 30, 40, 50
# Entrenando con 7 épocas, tasa de aprendizaje 8, dropout 9, capas 70, 80, 90
#
# --- Variación con listas de diferentes longitudes ---
#
# Entrenando con 1 épocas, tasa de aprendizaje 2, dropout 3, capas [10, 20, 30, 20, 10]
# Entrenando con 4 épocas, tasa de aprendizaje 5, dropout 6, capas [30, 40, 50, 40, 30, 20]
# Entrenando con 7 épocas, tasa de aprendizaje 8, dropout 9, capas [70, 80, 90]

# %%
for i in range(2, 4):
    print(i)
# Out:
# 2
# 3

# %%
def sumar_y_multiplicar(a,b):
    return a+b,a*b
 
a,b=sumar_y_multiplicar(3,4)
print(a)
print(b)
# Out:
# 7
# 12
