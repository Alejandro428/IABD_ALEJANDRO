# %%
# Actividad 2: Análisis Univariado Visual con Orange Data Mining
# Orange Data Mining es una fantástica herramienta 'no-code' que nos permite visualizar los conceptos del análisis de datos sin necesidad de programar. Refuerza la intuición detrás de las operaciones que luego realizamos con código. En esta actividad, replicarás el análisis univariado de forma visual.

# Instrucción Adicional: Utiliza la herramienta de anotación del lienzo para escribir y documentar las 
# respuestas a las preguntas guía de cada paso directamente en tu flujo de trabajo de Orange.

# Paso 1: Carga de Datos

# Abre Orange y arrastra el widget "File" al lienzo.

# Haz doble clic en él para cargar el mismo fichero movies.csv que has estado utilizando. 
# Orange detectará automáticamente las columnas y sus tipos de datos.



# Paso 2: Análisis Cuantitativo con el widget "Distributions"

# Sugerencia: Mientras exploras en Orange, ten abierto tu cuaderno de Python y genera los mismos histogramas con seaborn. 
# ¡La comparación es la clave del aprendizaje!

# Arrastra el widget "Distributions" al lienzo y conéctalo al widget "File".



# Ábrelo y selecciona primero la variable production_budget.



# Preguntas guía (production_budget):

# ¿Qué te dice la forma del histograma sobre los presupuestos? ¿Es simétrica o está sesgada?

# ¿Qué te dicen los estadísticos (media, mediana) que aparecen junto al gráfico? 
# ¿Confirman la asimetría que ves? Una gran diferencia entre media y mediana es un claro indicador de asimetría.



# Compara este histograma con el que creaste usando seaborn. ¿Son idénticos?



# Explora otras variables cuantitativas:



# Ahora selecciona domestic_gross y worldwide_gross. ¿Son también asimétricas?

# "A ojo", ¿cuál de las dos distribuciones parece tener valores más altos en general? ¿Tiene sentido esto? ¿Por qué?



# Paso 3: Análisis Categórico con el widget "Distributions"

# Sugerencia: De nuevo, te animamos a generar los gráficos de barras correspondientes en Python con seaborn.countplot() para validar tus hallazgos.

# En el mismo widget, selecciona la variable categórica genre.
# Preguntas guía (genre):


# ¿Qué tipo de gráfico ves ahora?

# ¿Cuáles son los 3 géneros más frecuentes? Compara el resultado con lo que obtuviste con .value_counts() en Pandas.

# Explora otras variables categóricas:

# Ahora selecciona mpaa_rating. ¿Qué clasificación por edades es la más común en el dataset?


# Compara visualmente la distribución de genre con la de mpaa_rating. ¿Cuál de las dos variables tiene una mayor diversidad de categorías?


# Supongamos ahora que tienes una prima de 12 de años a la que tus tíos te ha pedido que lleves al cine varios fin de semana durante este año ... ¿lo tendrás fácil?

# Paso 4: Comparando "Distributions" con "Feature Statistics"

# Vuelve al lienzo de Orange. Arrastra ahora el widget "Feature Statistics" y conéctalo también al widget "File".


# Abre el nuevo widget. Verás una tabla resumen de todas las variables.


# Preguntas guía:

# ¿Cuál es la principal diferencia entre la información que te da este widget y la que te da "Distributions"?

# ¿Qué widget usarías para tener una visión general y rápida de TODAS tus variables a la vez?
#  ¿Y cuál para explorar UNA SOLA variable en detalle y ver su distribución gráfica?

# Reflexiona

# Este ejercicio te ayuda a:

# Reforzar visualmente los conceptos de histograma y gráfico de barras.
# Conectar conceptos y entender que el código y las herramientas visuales son dos caminos para llegar al mismo resultado analítico.
# Distinguir herramientas para análisis general (Feature Statistics) vs. específico (Distributions).
