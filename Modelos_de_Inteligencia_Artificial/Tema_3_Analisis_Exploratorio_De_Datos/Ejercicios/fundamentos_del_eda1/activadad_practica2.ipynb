# %%
# Actividad Práctica: Implementando tus Propias Funciones Estadísticas
# Aunque Pandas nos da funciones como `.describe()` que calculan todo automáticamente, un gran ejercicio para afianzar los conceptos es programar estos estadísticos desde cero. En esta actividad, crearás un cuaderno de Python para replicar algunos de estos cálculos.

# Instrucciones:

# Crea un nuevo cuaderno de Python. Define una lista de datos de ejemplo, como por ejemplo: datos = [10, 20, 22, 25, 30, 35, 38, 40, 50, 55].

datos = [10, 20, 22, 25, 30, 35, 38, 40, 50, 55]

# %%
# Función 1 - calcular_media(lista): Esta función debe recibir una lista de números y devolver su media. 
# Pista: La media es la suma de todos los valores dividida por el número total de valores.

def calcular_media(lista):
    media = 0
    for i in lista:
        media+= i
    return media/len(lista)

print(datos)
# Out:
# [10, 20, 22, 25, 30, 35, 38, 40, 50, 55]

# %%
# Función 2 - calcular_mediana(lista): Esta función debe devolver la mediana. Pista: 
# Primero necesitarás ordenar la lista. Luego, si el número de elementos es impar, la mediana es el valor central. 
# Si es par, es el promedio de los dos valores centrales.

def calcular_media(lista):
    lista.sort()
    es_par = len(lista) % 2 == 0
    if(es_par):
        
    else:
        return

# %%
# Función 3 - calcular_cuartiles(lista): Esta es la más desafiante. Debe devolver el primer cuartil (Q1) y el tercer cuartil (Q3). Pista: Una vez ordenada la lista, Q1 es la mediana de la primera mitad de los datos (sin incluir la mediana si el total es impar) y Q3 es la mediana de la segunda mitad.

# %%
# Función 4 - analizar_datos(lista): Una función principal que llame a las tres anteriores e imprima los resultados de forma clara.
# Comprobación: Compara los resultados de tus funciones con los que ofrece el método .describe() de Pandas para la misma lista de datos. ¿Coinciden?
