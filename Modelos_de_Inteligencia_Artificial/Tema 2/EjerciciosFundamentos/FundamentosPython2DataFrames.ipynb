# %%
import pandas as pd
# 1 Creando una tabla de datos
# Se define un diccionario con 2 claves, nombre y edad
ejemploDatos = {
    "Nombre": ["Alejandro", "Dani", "Martín"],
    "Edad": [18, 21, 22],
}
# Se define una variable df, que contiene el dataframe del ejemplo del diccionario anterior
df = pd.DataFrame(ejemploDatos)
# Imprime el objeto
print(df)
# Out:
#       Nombre  Edad
# 0  Alejandro    18
# 1       Dani    21
# 2     Martín    22

# %%
# 2 Inspección de atributos


print("Dimensiones:", df.shape)
print("Columnas:", df.columns)
# Out:
# Dimensiones: (3, 2)
# Columnas: Index(['Nombre', 'Edad'], dtype='object')
