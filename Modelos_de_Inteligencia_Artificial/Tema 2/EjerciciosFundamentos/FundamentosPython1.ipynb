# %%
# 1 Manipulación de listas

# PARTE 1
listaEjemplo = [5, 7, 4, 3, 8]
# PARTE 2
listaEjemplo.append(7)
# PARTE 3
del listaEjemplo[1]
# listaEjemplo.pop(1)

# Creación de un Diccionario

# PARTE 1
cocheEjercicio = {
    "marca" : "Megane",
    "modelo" : "A3",
    "año" : 2004
}

# PARTE 2
cocheEjercicio["color"] = "Azul"

# 3 Bucle para sumar

# PARTE 1
numeros = [1, 2, 3, 4, 5]

# PARTE 2
suma = 0
for numero in numeros:
    suma += numero

print("La suma total es de " , suma)
# Out:
# La suma total es de  15
